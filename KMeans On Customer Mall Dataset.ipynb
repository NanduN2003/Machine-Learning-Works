# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib inline

# %%
df= pd.read_csv("C:/Users/neela/Downloads/[01] Cutomer Mall Dataset-20221212T054052Z-001/[01] Cutomer Mall Dataset/Mall_Customers.csv")

# %%
df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
df.shape
# Out:
# (200, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Gender                  200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %%
df.tail()
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83

# %%
df.dtypes
# Out:
# CustomerID                 int64
# Gender                    object
# Age                        int64
# Annual Income (k$)         int64
# Spending Score (1-100)     int64
# dtype: object

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]>

# %%
df.describe()
# Out:
#        CustomerID         Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000  200.000000          200.000000              200.000000
# mean   100.500000   38.850000           60.560000               50.200000
# std     57.879185   13.969007           26.264721               25.823522
# min      1.000000   18.000000           15.000000                1.000000
# 25%     50.750000   28.750000           41.500000               34.750000
# 50%    100.500000   36.000000           61.500000               50.000000
# 75%    150.250000   49.000000           78.000000               73.000000
# max    200.000000   70.000000          137.000000               99.000000

# %%
df.corr()
# Out:
#                         CustomerID       Age  Annual Income (k$)  \
# CustomerID                1.000000 -0.026763            0.977548
# Age                      -0.026763  1.000000           -0.012398
# Annual Income (k$)        0.977548 -0.012398            1.000000
# Spending Score (1-100)    0.013835 -0.327227            0.009903
#
#                         Spending Score (1-100)
# CustomerID                            0.013835
# Age                                  -0.327227
# Annual Income (k$)                    0.009903
# Spending Score (1-100)                1.000000

# %%
df.isnull().sum()
# Out:
# CustomerID                0
# Gender                    0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
plt.figure(figsize=(8,8))
sns.heatmap(df.corr(),annot=False)
# Out:
# <AxesSubplot:>

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['Gender'].value_counts()
# Out:
# Female    112
# Male       88
# Name: Gender, dtype: int64

# %%
labels = ['Female', 'Male']
size = [100, 80]
colors = ['lightgreen', 'orange']
explode = [0, 0.1]
plt.rcParams['figure.figsize'] = (7, 7)
plt.pie(size, colors = colors, explode = explode, labels = labels, shadow = True, autopct = '%.2f%%')
plt.title('A pie chart Representing the Gender')
plt.axis('off')
plt.legend()
plt.show()

# %%
genders = df.Gender.value_counts()
plt.figure(figsize=(10,4))
sns.barplot(x=genders.index, y=genders.values)
plt.show()

# %%
sns.boxplot(data=df,y= 'Age',x='Gender')
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='Age'>

# %%
plt.figure(figsize=(10, 8))
sns.distplot(df['Age'])
plt.title('Distribution of Age', fontsize = 20)
plt.xlabel('Range of Age')
plt.ylabel('Count')
# Out:
# C:\Users\neela\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0, 0.5, 'Count')

# %%
plt.rcParams['figure.figsize'] = (30, 8)
sns.countplot(df['Age'])
plt.title('Distribution of Age', fontsize = 20)
plt.show()
#We can see the pattern between 55-66 except the age 59,60 the frequency of visit to mall are less but even their is an 59,60
#People at Age 32 are the Most Frequent Visitors in the Mall.
#
# Out:
# C:\Users\neela\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.distplot(df['Annual Income (k$)'])
plt.title('Distribution of Annual Income', fontsize = 20)
plt.xlabel('Range of Annual Income')
plt.ylabel('Count')
plt.show()
#Majorly the people mentioned in the datasets has an ample annual income from $50k to $80K
# Out:
# C:\Users\neela\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(10, 6))
sns.distplot(df['Spending Score (1-100)'])
plt.title('Distribution of Spending Score (1-100)', fontsize = 20)
plt.xlabel('Range of Spending Score (1-100)')
plt.ylabel('Count')
#The maximum range of spending score is between 40 to 60.
# Out:
# C:\Users\neela\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0, 0.5, 'Count')

# %%
plt.scatter(df['Age'],df['Spending Score (1-100)'])
plt.xlabel('Age')
plt.ylabel('Spending Score')
# Out:
# Text(0, 0.5, 'Spending Score')

# %%
plt.scatter(df['Age'],df['Annual Income (k$)'])
plt.xlabel('Age')
plt.ylabel('Spending Score')
# Out:
# Text(0, 0.5, 'Spending Score')

# %%
sns.pairplot(df)

# %%
#Here the column customerID wont be anyhow helful to us so we will drop that column

# %%
sns.pairplot(df)

# %%
from sklearn import preprocessing
x = df[['Age' ,'Spending Score (1-100)']]
x_scaled = preprocessing.scale(x)

# %%
from sklearn.cluster import KMeans

wcss = []
for i in range(1, 11):
  km = KMeans(n_clusters = i, init = 'k-means++', max_iter = 300, n_init = 10, random_state = 0)
  km.fit(x)
  wcss.append(km.inertia_)
  
plt.plot(range(1, 11), wcss)
plt.title('The Elbow Method')
plt.xlabel('No. of Clusters')
plt.ylabel('wcss')
plt.show()
# Out:
# C:\Users\neela\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:881: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %% [markdown]
# As you can see that

# %%
kmeans = KMeans(3)
kmeans.fit(x_scaled)
data_with_clusters = df.copy()
data_with_clusters['Clusters'] = kmeans.fit_predict(x_scaled) 
data_with_clusters.head()
# Out:
#    Gender  Age  Annual Income (k$)  Spending Score (1-100)  Clusters
# 0    Male   19                  15                      39         1
# 1    Male   21                  15                      81         0
# 2  Female   20                  16                       6         1
# 3  Female   23                  16                      77         0
# 4  Female   31                  17                      40         1

# %%
plt.scatter(df['Age'],df['Spending Score (1-100)'], c=data_with_clusters['Clusters'], cmap='rainbow')
plt.title('Spending Score and Age', Fontsize=15)
plt.xlabel('Age')
plt.ylabel('Spending Score (1-100)')
plt.show()
# Out:
# C:\Users\neela\AppData\Local\Temp/ipykernel_16780/1805523094.py:2: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.title('Spending Score and Age', Fontsize=15)

# %%
kmeans = KMeans(4)
kmeans.fit(x_scaled)
data_with_clusters = df.copy()
data_with_clusters['Clusters'] = kmeans.fit_predict(x_scaled) 
data_with_clusters.head()
# Out:
#    Gender  Age  Annual Income (k$)  Spending Score (1-100)  Clusters
# 0    Male   19                  15                      39         0
# 1    Male   21                  15                      81         2
# 2  Female   20                  16                       6         0
# 3  Female   23                  16                      77         2
# 4  Female   31                  17                      40         0

# %%
plt.scatter(df['Age'],df['Spending Score (1-100)'], c=data_with_clusters['Clusters'], cmap='rainbow')
plt.title('Spending Score and Age', Fontsize=15)
plt.xlabel('Age')
plt.ylabel('Spending Score (1-100)')
plt.show()
# Out:
# C:\Users\neela\AppData\Local\Temp/ipykernel_16780/1805523094.py:2: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.title('Spending Score and Age', Fontsize=15)

# %%
kmeans = KMeans(5)
kmeans.fit(x_scaled)
data_with_clusters = df.copy()
data_with_clusters['Clusters'] = kmeans.fit_predict(x_scaled) 
data_with_clusters.head()
# Out:
#    Gender  Age  Annual Income (k$)  Spending Score (1-100)  Clusters
# 0    Male   19                  15                      39         3
# 1    Male   21                  15                      81         1
# 2  Female   20                  16                       6         0
# 3  Female   23                  16                      77         1
# 4  Female   31                  17                      40         3

# %%
plt.scatter(df['Age'],df['Spending Score (1-100)'], c=data_with_clusters['Clusters'], cmap='rainbow')
plt.title('Spending Score and Age', Fontsize=15)
plt.xlabel('Age')
plt.ylabel('Spending Score (1-100)')
plt.show()
# Out:
# C:\Users\neela\AppData\Local\Temp/ipykernel_16780/1805523094.py:2: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.title('Spending Score and Age', Fontsize=15)
